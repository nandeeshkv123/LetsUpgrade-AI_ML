# %% [markdown]
# # Attrition Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset1=pd.read_csv("general_data.csv")
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# # Data Treatment

# %%
dataset1.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset1.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset2=dataset1[['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
       'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
       'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
dataset2
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
dataset2=dataset1[['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
       'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
       'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']].median()
dataset2
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                  2205.5
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
dataset2=dataset1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
dataset2
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11               10.0                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               5                        0                     2

# %%
dataset2=dataset1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
dataset2
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
dataset2=dataset1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
dataset2
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
dataset3=dataset1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
dataset3
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
dataset2=dataset1[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mean()
dataset2
# Out:
# Age                           36.923810
# DistanceFromHome               9.192517
# Education                      2.912925
# MonthlyIncome              65029.312925
# NumCompaniesWorked             2.694830
# PercentSalaryHike             15.209524
# TotalWorkingYears             11.279936
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# YearsSinceLastPromotion        2.187755
# YearsWithCurrManager           4.123129
# dtype: float64

# %%
box_plot=dataset1.Age
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eb8ad29cc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eb8ad29e88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eb8ad29408>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eb8ad26b48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eb8ad22c08>],
#  'means': []}

# %%
box_plot=dataset1.MonthlyIncome
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eb8ad91e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eb8ad8dc08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eb8ad91948>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eb8ad8dd88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eb8ad86c48>],
#  'means': []}

# %%
box_plot=dataset1.YearsAtCompany
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eb8adfdc48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eb8adfddc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eb8adfd4c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eb8ae02dc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eb8ae02e48>],
#  'means': []}

# %% [markdown]
# # Data visualisation

# %%
# get a count no of employee stayed and left the company
dataset1["Attrition"].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
#visualise the no of people stayed and left the company 
sns.countplot(dataset1["Attrition"])

# %%
#show the employee that stayed and left by age 
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,8))
sns.countplot(x="Age",hue="Attrition",data=dataset1,palette='colorblind')

# %%
# Get the correlation
dataset1.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.006963  -0.035706            NaN
# DistanceFromHome         0.006963          1.000000  -0.008638            NaN
# Education               -0.035706         -0.008638   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.008649         -0.001097  -0.009680            NaN
# JobLevel                -0.002884         -0.037329   0.045746            NaN
# MonthlyIncome           -0.044314         -0.021607   0.006410            NaN
# NumCompaniesWorked       0.299243         -0.013843  -0.016250            NaN
# PercentSalaryHike       -0.033137          0.038125  -0.040531            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.031753          0.011169   0.001261            NaN
# ...

# %%
# visualise the correlation
plt.subplots(figsize=(14,14))
sns.heatmap(dataset1.corr(),annot=True,fmt='.0%')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
dataset1.Attrition=dataset1.Attrition.map({"Yes":1,"No":0})
dataset1.Gender=dataset1.Gender.map({"Male":1,"Female":0})
dataset1.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0       0  ...                 1.0      Y                11              8
# ...

# %%
plt.title("Attrition and DistanceFromHome")
sns.barplot(x=dataset1["Attrition"],y=dataset1["DistanceFromHome"])

# %% [markdown]
# # statistical tets(Mannwhitney)

# %%
import pandas as pd
dataset3=pd.read_csv("general_data.csv")
dataset3=dataset[dataset["Attrition"] =="Yes"]
dataset3.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 1    31       Yes  Travel_Frequently  Research & Development
# 6    28       Yes      Travel_Rarely  Research & Development
# 13   47       Yes         Non-Travel  Research & Development
# 28   44       Yes  Travel_Frequently  Research & Development
# 30   26       Yes      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset4=pd.read_csv("general_data.csv")
dataset4=dataset[dataset["Attrition"] =="No"]
dataset4.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
# 5          3  Life Sciences              1           6  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
# mannwhitney test
# Attrition vs DistanceFromHome
from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(dataset3.DistanceFromHome,dataset4.DistanceFromHome)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and distance from home.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 1312110.0 0.4629185205822659
# Accept null hypothesis

# %% [markdown]
# as the p value 0.46>0.05 so the null hypothesis(H0) is accepted and the alternate hypothesis is rejected(Ha)
# H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition
# (N)
# Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)

# %%
# Attrition vs Income
from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(dataset3.MonthlyIncome,dataset4.MonthlyIncome)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and MonthlyIncome.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 1264900.5 0.053577283839938566
# Accept null hypothesis

# %% [markdown]
# As the P value is 0.05 which is equal to 0.05, the H0 is accepted and ha is rejected.
# H0: There is no significant differences in the income between attrition (Y) and attirition (N)
# Ha: There is significant differences in the income between attrition (Y) and attirition (N)

# %%
# Attrition Vs Total Working Years

from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(dataset3.TotalWorkingYears,dataset4.TotalWorkingYears)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and TotalWorkingYears.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 909954.0 2.8897554531400447e-39
# Reject null hypothesis

# %% [markdown]
# As the P value < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Total Working Years between attrition (Y) and attirition
# (N)
# Ha: There is significant differences in the Total Working Years between attrition (Y) and attirition (N)

# %%
# Attrition Vs  YearsWithCurrentManager
from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(dataset3.YearsWithCurrManager,dataset4.YearsWithCurrManager)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and  YearsWithCurrentManager.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 957253.5 1.2365483142169853e-31
# Reject null hypothesis

# %% [markdown]
# As the P value is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)
# Ha: There is significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)

# %% [markdown]
# # Statistical Tests (Separate T Test)

# %%
from scipy.stats import ttest_ind
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Attrition Vs Distance From Home
stats,p=ttest_ind(dataset3.DistanceFromHome,dataset4.DistanceFromHome)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and  DistanceFromHome.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# -0.6460416038042738 0.518286042805572
# Accept null hypothesis

# %% [markdown]
# As the P value is again 0.5, which is > than 0.05, the H0 is accepted and ha is rejected.
# H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition
# (N)
# Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)

# %%
# Attrition Vs Years With Current Manager
stats,p=ttest_ind(dataset3.YearsWithCurrManager,dataset4.YearsWithCurrManager)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and  YearsWithCurrManager.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# -10.499379408703438 1.7339322652918153e-25
# Reject null hypothesis

# %% [markdown]
# As the P value is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)
# Ha: There is significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)

# %% [markdown]
# # Unsupervised Learning - Correlation Analysis

# %% [markdown]
# In order to find the interdependency of the variables DistanceFromHome, MonthlyIncome,
# TotalWorkingYears, YearsAtCompany, YearsWithCurrManager from that of Attrition, we executed
# the Correlation Analysis as follows.

# %%
dataset=pd.read_csv("general_data.csv")
from scipy.stats import pearsonr
dataset['TotalWorkingYears']=dataset['TotalWorkingYears'].fillna(11.28)
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
stats, p=pearsonr(dataset1.Attrition, dataset1.DistanceFromHome)
print(stats, p)
# Out:
# -0.00973014101017966 0.5182860428050771

# %%
stats, p=pearsonr(dataset1.Attrition, dataset1.MonthlyIncome)
print(stats, p)
# Out:
# -0.031176281698115007 0.03842748490600132

# %%
stats, p=pearsonr(dataset1.Attrition, dataset1.YearsAtCompany)
print(stats, p)
# Out:
# -0.1343922139899772 3.1638831224877484e-19

# %%
stats, p=pearsonr(dataset1.Attrition, dataset1.YearsWithCurrManager)
print(stats, p)
# Out:
# -0.15619931590162842 1.7339322652900218e-25

# %% [markdown]
# The inference of the above analysis are as follows:
# Attrition & DistanceFromHome:
# As r = -0.009, there’s low negative correlation between Attrition and DistanceFromHome
# As the P value of 0.518 is > 0.05, we are accepting H0 and hence there’s no significant correlation
# between Attrition & DistanceFromHome
#
# Attrition & MonthlyIncome:
# As r = -0.031, there’s low negative correlation between Attrition and MonthlyIncome
# As the P value of 0.038 is < 0.05, we are accepting Ha and hence there’s significant correlation
# between Attrition & MonthlyIncome
#
# Attrition & YearsAtCompany:
# As r = -0.1343, there’s low negative correlation between Attrition and YearsAtCompany
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & YearsAtCompany
#
# Attrition & YearsWithCurrManager:
# As r = -0.1561, there’s low negative correlation between Attrition and YearsWithCurrManager
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & YearsWithCurrManager
